# %%
from math import sqrt

class calc(): 
    def __init__(self,input1,input2,input3,input4,input5):
        self.input1=input1
        self.input2=input2
        self.input3=input3
        self.input4=input4
        self.input5=input5
    
    def addition(num1, num2):
        print(f'Addition= {num1+num2}')
    
    def subtraction(num1,num2):
        print(f'Subtraction = {num1-num2}')
    
    def multiplication(num1,num2):
        print(f'Multiplication= {num1*num2}')

    def division(num1,num2):
        print(f'Division= {num1/num2}')
    
    def average(num1,num2):
        print(f"Average= {(num1+num2)/2}")
    
    def minimum(num1,num2,num3,num4,num5):
        print(f"Minimum= {min(num1,num2,num3,num4,num5)}")
        
    def maximum(num1,num2,num3,num4,num5):
        print(f"Maximum= {max(num1,num2,num3,num4,num5)}")
        
    def sqrt(num1):
        print(f"Square Root= {sqrt(num1)}")
        
    def squared(num1):
        print(f"Squared= {num1*num1}")
        
    def cubed(num1):
        print(f"Cubed= {(num1*num1)*num1}")
        
    def cuberoot(num1):
        print(f"Cube root= {num1**(1/3)}")
        
    def mean(num1,num2,num3,num4,num5):
        print(f"mean= {(num1+num2+num3+num4+num5)/5}")
        
    def median(num1,num2,num3,num4,num5):
        med=[num1,num2,num3,num4,num5]
        sort_med=sorted(med)
        print(f"Median= {sort_med[2]}")
        
    def range1(num1,num2,num3,num4,num5):
        print(f"Range= {(max(num1,num2,num3,num4,num5))-(min(num1,num2,num3,num4,num5))}")
        
    def inverse(num1):
        print(f"Inverse= {num1**-1}")
    
while True:
    print("Chose from the following menu: ")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Average")
    print("6. Minimum")
    print("7. Maximum")
    print("8. Square Root")
    print("9. Spuared")
    print("10. Cubed")
    print("11. Cube Root")
    print("12. Mean")
    print("13. Median")
    print("14. Range")
    print("15. Inverse")
    print("16. Exit")
    
    choice=int(input("Enter your choice (1-16)"))
    
    if choice==1:
        num1=int(input("Enter 1st number: "))
        num2=int(input("Enter second number: "))
        calc.addition(num1,num2)
        
    elif choice==2:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.subtraction(num1,num2)
    
    elif choice==3:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.multiplication(num1,num2)
    
    elif choice==4:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        if num2==0:
            print("Infinity")
        else:
            calc.division(num1,num2)
    elif choice==5:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        calc.average(num1,num2)
    
    elif choice==6:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        num3=int(input("Enter 3rd Number:"))
        num4=int(input("Enter 4th Number:"))
        num5=int(input("Enter 5th Number:"))
        calc.minimum(num1,num2,num3,num4,num5)
    
    elif choice==7:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        num3=int(input("Enter 3rd Number:"))
        num4=int(input("Enter 4th Number:"))
        num5=int(input("Enter 5th Number:"))
        calc.maximum(num1,num2,num3,num4,num5)
        
    elif choice==8:
        num1=int(input("Enter a Number:"))
        calc.sqrt(num1)
        
    elif choice==9:
        num1=int(input("Enter a Number:"))
        calc.squared(num1)
        
    elif choice==10:
        num1=int(input("Enter a Number:"))
        calc.cubed(num1)
        
    elif choice==11:
        num1=int(input("Enter a Number:"))
        calc.cuberoot(num1)
        
    elif choice==12:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        num3=int(input("Enter 3rd Number:"))
        num4=int(input("Enter 4th Number:"))
        num5=int(input("Enter 5th Number:"))
        calc.mean(num1,num2,num3,num4,num5)
        
    elif choice==13:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        num3=int(input("Enter 3rd Number:"))
        num4=int(input("Enter 4th Number:"))
        num5=int(input("Enter 5th Number:"))
        calc.median(num1,num2,num3,num4,num5)
        
    elif choice==14:
        num1=int(input("Enter 1st Number:"))
        num2=int(input("Enter 2nd Number:"))
        num3=int(input("Enter 3rd Number:"))
        num4=int(input("Enter 4th Number:"))
        num5=int(input("Enter 5th Number:"))
        calc.range1(num1,num2,num3,num4,num5)
        
    elif choice==15:
        num1=float(input("Enter a Number or decimal:"))
        calc.inverse(num1)
            
    elif choice==16:
        break
    else:
        print("Invalid input")
# Out:
# Chose from the following menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Average
# 6. Minimum
# 7. Maximum
# 8. Square Root
# 9. Spuared
# 10. Cubed
# 11. Cube Root
# 12. Mean
# 13. Median
# 14. Range
# 15. Inverse
# 16. Exit
# Enter your choice (1-16)7
# Enter 1st Number:6
# Enter 2nd Number:3
# Enter 3rd Number:9
# Enter 4th Number:4
# Enter 5th Number:8
# Maximum= 9
# Chose from the following menu:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Average
# 6. Minimum
# 7. Maximum
# 8. Square Root
# 9. Spuared
# 10. Cubed
# 11. Cube Root
# 12. Mean
# 13. Median
# 14. Range
# 15. Inverse
# 16. Exit
# Enter your choice (1-16)16

# %% [markdown]
# ### PA6, Ryan Fox, Version 1
